# %%
import os
import cv2
import keras
from keras.models import Sequential, Model
from keras.layers import Input, BatchNormalization, Activation, Conv3D, Dropout, Concatenate, AveragePooling3D, MaxPooling3D, Dense, Flatten, GlobalAveragePooling2D
from keras.activations import linear, softmax
from keras.applications import densenet

# Code to train T3D model
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam, SGD
import keras.backend as K
import traceback

__all__ = ['DenseNet', 'densenet121', 'densenet161']  # with DropOut
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def _DenseLayer(prev_layer, growth_rate, bn_size, drop_rate):
    if prev_layer is None:
        # print('No Layer previous to Dense Layers!!')
        return None
    else:
        x = BatchNormalization()(prev_layer)
    x = Activation('relu')(x)
    x = Conv3D(filters=bn_size * growth_rate, kernel_size=1, strides=1, padding='same')(x)
    x = Dropout(drop_rate)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv3D(filters=growth_rate, kernel_size=3, strides=1, padding='same')(x)
    x = Dropout(drop_rate)(x)

    return x

# %%
def _DenseBlock(prev_layer, num_layers, bn_size, growth_rate, drop_rate):
    x = prev_layer
    for i in range(num_layers):
        layer = _DenseLayer(x, growth_rate, bn_size, drop_rate)
        if layer is None:
            print('Dense Block not created as no previous layers found!!')
            return None
        else:
            x = layer
    return x

# %%
def _Transition(prev_layer, num_output_features):

    # print('In _Transition')
    x = BatchNormalization()(prev_layer)
    x = Activation('relu')(x)
    x = Conv3D(filters=num_output_features, kernel_size=1, strides=1, use_bias=False, padding='same')(x)
    x = AveragePooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2))(x)
    # print('Completed _Transition')
    return x

# %%
def _TTL(prev_layer):
    # print('In _TTL')
    b1 = BatchNormalization()(prev_layer)
    b1 = Activation('relu')(b1)
    # b1 = Conv3D(128, kernel_size=(1), strides=1, use_bias=False, padding='same')(b1)
    b1 = Conv3D(128, kernel_size=(1, 3, 3), strides=1, use_bias=False, padding='same')(b1)

    b2 = BatchNormalization()(prev_layer)
    b2 = Activation('relu')(b2)
    b2 = Conv3D(128, kernel_size=(3, 3, 3), strides=1, use_bias=False, padding='same')(b2)

    b3 = BatchNormalization()(prev_layer)
    b3 = Activation('relu')(b3)
    b3 = Conv3D(128, kernel_size=(4, 3, 3), strides=1, use_bias=False, padding='same')(b3)

    x = keras.layers.concatenate([b1, b2, b3], axis=1)
    # print('completed _TTL')
    return x

# %%
def DenseNet3D(input_shape, growth_rate=32, block_config=(6, 8, 8, 10),
               num_init_features=32, bn_size=4, drop_rate=0, num_classes=2):
    r"""Densenet-BC model class, based on
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`
    Args:
        growth_rate (int) - how many filters to add each layer (`k` in paper)
        block_config (list of 4 ints) - how many layers in each pooling block
        num_init_features (int) - the number of filters to learn in the first convolution layer
        bn_size (int) - multiplicative factor for number of bottle neck layers
          (i.e. bn_size * k features in the bottleneck layer)
        drop_rate (float) - dropout rate after each dense layer
        num_classes (int) - number of classification classes
    """
    #-----------------------------------------------------------------
    inp_2d = (Input(shape=(224,224,3), name='2d_input'))
    pretrained_densenet = densenet.DenseNet169(include_top=False, input_shape=(224,224,3), input_tensor=inp_2d, weights='imagenet')
    for layer in pretrained_densenet.layers:
        layer.trainable = False
    #-----------------------------------------------------------------

    # First convolution-----------------------
    inp_3d = (Input(shape=input_shape, name='3d_input'))


    # need to check padding
    x = (Conv3D(num_init_features, kernel_size=(3, 7, 7),
                strides=2, padding='same', use_bias=False))(inp_3d)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # need to check padding
    x = MaxPooling3D(pool_size=(3, 3, 3), strides=(
        2, 2, 2), padding='valid')(x)

    # Each denseblock
    num_features = num_init_features
    for i, num_layers in enumerate(block_config):
        # print('Pass', i)
        x = _DenseBlock(x, num_layers=num_layers,
                        bn_size=bn_size, growth_rate=growth_rate, drop_rate=drop_rate)

        num_features = num_features + num_layers * growth_rate

        if i != len(block_config) - 1:
            # print('Not Last layer, so adding Temporal Transition Layer')

            x = _TTL(x)
            # num_features = 128*3

            x = _Transition(x, num_output_features=num_features)
            num_features = num_features

    # Final batch norm
    x = BatchNormalization()(x)

    x = Activation('relu')(x)
    x = AveragePooling3D(pool_size=(1, 7, 7))(x)
    x = Flatten(name='flatten_3d')(x)
    x = Dense(512, activation='relu')(x)
    #--------------fron 2d densenet model-----------------
    y = GlobalAveragePooling2D(name='avg_pool_densnet2d')(pretrained_densenet.output)
    y = Dense(256, activation='relu')(y)

    #-----------------------------------------------------
    x = keras.layers.concatenate([x,y])
    x = Dropout(0.65)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.35)(x)
    out = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=[inp_2d, inp_3d], outputs=[out])
    model.summary()

    return model

# %%
# the below model has the lowest Top-1 error in ImageNet Data Set:
def densenet161_3D_DropOut(input_shape, nb_classes):
    model = DenseNet3D(input_shape, growth_rate=36, block_config=(
        6, 10, 20, 16), num_init_features=48, drop_rate=0.6, num_classes=2)
    return model


def densenet121_3D_DropOut(input_shape, nb_classes):
    """Constructs a DenseNet-121_DropOut model.
    """
    model = DenseNet3D(input_shape, num_init_features=64, growth_rate=32,
                       block_config=(1, 0, 0, 1), drop_rate=0.6, num_classes=nb_classes)
    return model

# %%
FRAMES_PER_VIDEO = 20
FRAME_HEIGHT = 256
FRAME_WIDTH = 256
FRAME_CHANNEL = 3
NUM_CLASSES = 2
BATCH_SIZE = 5
EPOCHS = 100
MODEL_FILE_NAME = '/content/drive/My Drive/Deep Learning/Sub_32/T3D_saved_model.h5'

input_shape = (FRAME_HEIGHT,FRAME_WIDTH,FRAME_CHANNEL)
nb_classes = 2
sample_input = np.empty([FRAMES_PER_VIDEO, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNEL], dtype=np.uint8)
#model  = densenet161_3D_DropOut(sample_input.shape, nb_classes)

# %%
import os
import cv2
import numpy as np
from keras.utils.np_utils import to_categorical
import random

ROOT_PATH = '/content/drive/My Drive/Deep Learning/Dataset'

def get_video_frames(src, fpv, frame_height, frame_width):
    # print('reading video from', src)
    cap = cv2.VideoCapture(src)

    frames = []
    if not cap.isOpened():
        cap.open(src)
    ret = True
    while(True and ret):
        # Capture frame-by-frame
        ret, frame = cap.read()

        frames.append(frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything done, release the capture
    cap.release()

    rnd_idx = random.randint(5,len(frames)-5)
    rnd_frame = frames[rnd_idx]
    rnd_frame = cv2.resize(rnd_frame,(224,224)) #Needed for Densenet121-2d

    # Return fpv=10 frames
    step = len(frames)//fpv
    avg_frames = frames[::step]
    avg_frames = avg_frames[:fpv]
    avg_resized_frames = []
    for af in avg_frames:
        rsz_f = cv2.resize(af, (frame_width, frame_height))
        avg_resized_frames.append(rsz_f)
    return np.asarray(rnd_frame)/255.0,np.asarray(avg_resized_frames)


def get_video_and_label(index, data, frames_per_video, frame_height, frame_width):
    # Read clip and appropiately send the sports' class
    frame, clip = get_video_frames(os.path.join(
        ROOT_PATH, data['path'].values[index].strip()), frames_per_video, frame_height, frame_width)
    sport_class = data['class'].values[index]

    frame = np.expand_dims(frame, axis=0)
    clip = np.expand_dims(clip, axis=0)

    # print('Frame shape',frame.shape)
    # print('Clip shape',clip.shape)


    return frame, clip, sport_class


def video_gen(data, frames_per_video, frame_height, frame_width, channels, num_classes, batch_size=4):
    while True:
        # Randomize the indices to make an array
        indices_arr = np.random.permutation(data.count()[0])
        for batch in range(0, len(indices_arr), batch_size):
            # slice out the current batch according to batch-size
            current_batch = indices_arr[batch:(batch + batch_size)]

            # initializing the arrays, x_train and y_train
            clip = np.empty([0, frames_per_video, frame_height, frame_width, channels], dtype=np.float32)
            frame = np.empty([0, 224, 224, 3], dtype=np.float32)

            y_train = np.empty([0], dtype=np.int32)

            for i in current_batch:
                # get frames and its corresponding color for an traffic light
                single_frame, single_clip, sport_class = get_video_and_label(
                    i, data, frames_per_video, frame_height, frame_width)

                # Appending them to existing batch
                frame = np.append(frame, single_frame, axis=0)
                clip = np.append(clip, single_clip, axis=0)

                y_train = np.append(y_train, [sport_class])
            y_train = to_categorical(y_train, num_classes=num_classes)

            yield ([frame, clip], y_train)

# %%
bs_path = '/content/drive/My Drive/Deep Learning/Dataset'
d_train = pd.read_csv(os.path.join(bs_path, 'train.csv'))
d_valid = pd.read_csv(os.path.join(bs_path, 'valid.csv'))

# %%
video_train_generator = video_gen(
    d_train, FRAMES_PER_VIDEO, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNEL, nb_classes, batch_size=BATCH_SIZE)
video_val_generator = video_gen(
    d_valid, FRAMES_PER_VIDEO, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNEL, nb_classes, batch_size=BATCH_SIZE)

sample_input = np.empty(
    [FRAMES_PER_VIDEO, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNEL], dtype=np.uint8)

# %%
# Get Model
# model = densenet121_3D_DropOut(sample_input.shape, nb_classes)
model = densenet161_3D_DropOut(sample_input.shape, nb_classes)

checkpoint = ModelCheckpoint('/content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, mode='min',  ) #save_best_only=True, save_weights_only=True)
earlyStop = EarlyStopping(monitor='val_loss', mode='min', patience=100)
reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                    patience=20,
                                    verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)

callbacks_list = [checkpoint, reduceLROnPlat, earlyStop]
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# 2d_input (InputLayer)           (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 230, 230, 3)  0           2d_input[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 114, 114, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 56, 56, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 56, 56, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 56, 56, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 56, 56, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 56, 56, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 56, 56, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 56, 56, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 56, 56, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 56, 56, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 56, 56, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 56, 56, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 56, 56, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 56, 56, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 56, 56, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 56, 56, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 56, 56, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 56, 56, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 56, 56, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 56, 56, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 56, 56, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 56, 56, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 56, 56, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 56, 56, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 56, 56, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# 3d_input (InputLayer)           (None, 20, 256, 256, 0
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3d_118 (Conv3D)             (None, 10, 128, 128, 21168       3d_input[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 10, 128, 128, 192         conv3d_118[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 10, 128, 128, 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 4, 63, 63, 48 0           activation_119[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 4, 63, 63, 48 192         max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 4, 63, 63, 48 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_119 (Conv3D)             (None, 4, 63, 63, 14 7056        activation_120[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# dropout_108 (Dropout)           (None, 4, 63, 63, 14 0           conv3d_119[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 4, 63, 63, 14 576         dropout_108[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 4, 63, 63, 14 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_120 (Conv3D)             (None, 4, 63, 63, 36 140004      activation_121[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# dropout_109 (Dropout)           (None, 4, 63, 63, 36 0           conv3d_120[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 4, 63, 63, 36 144         dropout_109[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 4, 63, 63, 36 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3d_121 (Conv3D)             (None, 4, 63, 63, 14 5328        activation_122[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# dropout_110 (Dropout)           (None, 4, 63, 63, 14 0           conv3d_121[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 4, 63, 63, 14 576         dropout_110[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 4, 63, 63, 14 0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3d_122 (Conv3D)             (None, 4, 63, 63, 36 140004      activation_123[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# dropout_111 (Dropout)           (None, 4, 63, 63, 36 0           conv3d_122[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 4, 63, 63, 36 144         dropout_111[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 4, 63, 63, 36 0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3d_123 (Conv3D)             (None, 4, 63, 63, 14 5328        activation_124[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# dropout_112 (Dropout)           (None, 4, 63, 63, 14 0           conv3d_123[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 4, 63, 63, 14 576         dropout_112[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 4, 63, 63, 14 0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3d_124 (Conv3D)             (None, 4, 63, 63, 36 140004      activation_125[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 4, 63, 63, 36 0           conv3d_124[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 4, 63, 63, 36 144         dropout_113[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 4, 63, 63, 36 0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3d_125 (Conv3D)             (None, 4, 63, 63, 14 5328        activation_126[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# dropout_114 (Dropout)           (None, 4, 63, 63, 14 0           conv3d_125[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 4, 63, 63, 14 576         dropout_114[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 4, 63, 63, 14 0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_126 (Conv3D)             (None, 4, 63, 63, 36 140004      activation_127[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# dropout_115 (Dropout)           (None, 4, 63, 63, 36 0           conv3d_126[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 4, 63, 63, 36 144         dropout_115[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 4, 63, 63, 36 0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_127 (Conv3D)             (None, 4, 63, 63, 14 5328        activation_128[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# dropout_116 (Dropout)           (None, 4, 63, 63, 14 0           conv3d_127[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# dropout_204 (Dropout)           (None, 13, 7, 7, 144 0           conv3d_227[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 13, 7, 7, 144 576         dropout_204[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 7, 7, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 13, 7, 7, 144 0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 7, 7, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv3d_228 (Conv3D)             (None, 13, 7, 7, 36) 140004      activation_229[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 7, 7, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# dropout_205 (Dropout)           (None, 13, 7, 7, 36) 0           conv3d_228[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 7, 7, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 13, 7, 7, 36) 144         dropout_205[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 13, 7, 7, 36) 0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3d_229 (Conv3D)             (None, 13, 7, 7, 144 5328        activation_230[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# dropout_206 (Dropout)           (None, 13, 7, 7, 144 0           conv3d_229[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 7, 7, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 13, 7, 7, 144 576         dropout_206[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 7, 7, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 13, 7, 7, 144 0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 7, 7, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3d_230 (Conv3D)             (None, 13, 7, 7, 36) 140004      activation_231[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 7, 7, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# dropout_207 (Dropout)           (None, 13, 7, 7, 36) 0           conv3d_230[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 13, 7, 7, 36) 144         dropout_207[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 13, 7, 7, 36) 0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_231 (Conv3D)             (None, 13, 7, 7, 144 5328        activation_232[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 7, 7, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# dropout_208 (Dropout)           (None, 13, 7, 7, 144 0           conv3d_231[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 7, 7, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 13, 7, 7, 144 576         dropout_208[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 7, 7, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 13, 7, 7, 144 0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 7, 7, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3d_232 (Conv3D)             (None, 13, 7, 7, 36) 140004      activation_233[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# dropout_209 (Dropout)           (None, 13, 7, 7, 36) 0           conv3d_232[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 13, 7, 7, 36) 144         dropout_209[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 13, 7, 7, 36) 0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 7, 7, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3d_233 (Conv3D)             (None, 13, 7, 7, 144 5328        activation_234[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 7, 7, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# dropout_210 (Dropout)           (None, 13, 7, 7, 144 0           conv3d_233[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 7, 7, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 13, 7, 7, 144 576         dropout_210[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 7, 7, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 13, 7, 7, 144 0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3d_234 (Conv3D)             (None, 13, 7, 7, 36) 140004      activation_235[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# dropout_211 (Dropout)           (None, 13, 7, 7, 36) 0           conv3d_234[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 13, 7, 7, 36) 144         dropout_211[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 7, 7, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 13, 7, 7, 36) 0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1664)   6656        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# average_pooling3d_8 (AveragePoo (None, 13, 1, 1, 36) 0           activation_236[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1664)   0           bn[0][0]
# __________________________________________________________________________________________________
# flatten_3d (Flatten)            (None, 468)          0           average_pooling3d_8[0][0]
# __________________________________________________________________________________________________
# avg_pool_densnet2d (GlobalAvera (None, 1664)         0           relu[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          240128      flatten_3d[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          426240      avg_pool_densnet2d[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 768)          0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_212 (Dropout)           (None, 768)          0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          196864      dropout_212[0][0]
# __________________________________________________________________________________________________
# dropout_213 (Dropout)           (None, 256)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          32896       dropout_213[0][0]
# __________________________________________________________________________________________________
# dropout_214 (Dropout)           (None, 128)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 2)            258         dropout_214[0][0]
# ==================================================================================================
# Total params: 22,755,458
# Trainable params: 10,088,002
# Non-trainable params: 12,667,456
# __________________________________________________________________________________________________

# %%
#from keras.utils.vis_utils import plot_model
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Save the model architecture
with open('ver_4_gen_model_architecture.json', 'w') as f:
    f.write(model.to_json())

# %%
optim = Adam(lr=1e-4, decay=1e-6)
#optim = SGD(lr = 0.1, momentum=0.9, decay=1e-4, nesterov=True)
model.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_steps = len(d_train)//BATCH_SIZE
val_steps = len(d_valid)//BATCH_SIZE

# %%
history = model.fit_generator(
    video_train_generator,
    validation_data=video_val_generator,
    steps_per_epoch=train_steps,
    validation_steps=val_steps, 
    epochs=150, #EPOCHS,
    verbose=1,
    callbacks=callbacks_list
    #,workers=1 
     )
# Out:
# Epoch 1/150
# 59/59 [==============================] - 241s 4s/step - loss: 1.0684 - accuracy: 0.4475 - val_loss: 0.6181 - val_accuracy: 0.5800
#
# Epoch 00001: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.01-0.62.hdf5
# Epoch 2/150
# 59/59 [==============================] - 67s 1s/step - loss: 0.8136 - accuracy: 0.5120 - val_loss: 0.6557 - val_accuracy: 0.5106
#
# Epoch 00002: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.02-0.66.hdf5
# Epoch 3/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.8153 - accuracy: 0.5430 - val_loss: 0.6091 - val_accuracy: 0.5532
#
# Epoch 00003: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.03-0.61.hdf5
# Epoch 4/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.7329 - accuracy: 0.5189 - val_loss: 0.6746 - val_accuracy: 0.5106
#
# Epoch 00004: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.04-0.67.hdf5
# Epoch 5/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7707 - accuracy: 0.5017 - val_loss: 0.6434 - val_accuracy: 0.4255
#
# Epoch 00005: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.05-0.64.hdf5
# Epoch 6/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7265 - accuracy: 0.5739 - val_loss: 0.5632 - val_accuracy: 0.6596
#
# Epoch 00006: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.06-0.56.hdf5
# Epoch 7/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7659 - accuracy: 0.5052 - val_loss: 0.7206 - val_accuracy: 0.4894
#
# Epoch 00007: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.07-0.72.hdf5
# Epoch 8/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.7574 - accuracy: 0.5361 - val_loss: 0.6876 - val_accuracy: 0.4255
#
# Epoch 00008: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.08-0.69.hdf5
# Epoch 9/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7440 - accuracy: 0.4880 - val_loss: 0.6736 - val_accuracy: 0.6596
#
# Epoch 00009: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.09-0.67.hdf5
# Epoch 10/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7193 - accuracy: 0.5430 - val_loss: 0.7144 - val_accuracy: 0.5532
#
# Epoch 00010: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.10-0.71.hdf5
# Epoch 11/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7139 - accuracy: 0.5292 - val_loss: 0.7347 - val_accuracy: 0.5319
#
# Epoch 00011: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.11-0.73.hdf5
# Epoch 12/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6776 - accuracy: 0.6014 - val_loss: 0.6417 - val_accuracy: 0.5600
#
# Epoch 00012: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.12-0.64.hdf5
# Epoch 13/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.7115 - accuracy: 0.5773 - val_loss: 0.6158 - val_accuracy: 0.5319
#
# Epoch 00013: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.13-0.62.hdf5
# Epoch 14/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6930 - accuracy: 0.5636 - val_loss: 0.7579 - val_accuracy: 0.5745
#
# Epoch 00014: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.14-0.76.hdf5
# Epoch 15/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7110 - accuracy: 0.5773 - val_loss: 0.7118 - val_accuracy: 0.7021
#
# Epoch 00015: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.15-0.71.hdf5
# Epoch 16/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6880 - accuracy: 0.5945 - val_loss: 0.7202 - val_accuracy: 0.6383
#
# Epoch 00016: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.16-0.72.hdf5
# Epoch 17/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6612 - accuracy: 0.6151 - val_loss: 0.7293 - val_accuracy: 0.6596
#
# Epoch 00017: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.17-0.73.hdf5
# Epoch 18/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6819 - accuracy: 0.5842 - val_loss: 0.6308 - val_accuracy: 0.7872
#
# Epoch 00018: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.18-0.63.hdf5
# Epoch 19/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6503 - accuracy: 0.6014 - val_loss: 0.6036 - val_accuracy: 0.6809
#
# Epoch 00019: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.19-0.60.hdf5
# Epoch 20/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.7092 - accuracy: 0.5430 - val_loss: 0.6349 - val_accuracy: 0.7234
#
# Epoch 00020: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.20-0.63.hdf5
# Epoch 21/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6680 - accuracy: 0.5842 - val_loss: 0.6080 - val_accuracy: 0.7447
#
# Epoch 00021: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.21-0.61.hdf5
# Epoch 22/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5840 - accuracy: 0.7045 - val_loss: 0.5144 - val_accuracy: 0.7021
#
# Epoch 00022: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.22-0.51.hdf5
# Epoch 23/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6597 - accuracy: 0.6186 - val_loss: 0.5671 - val_accuracy: 0.7400
#
# Epoch 00023: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.23-0.57.hdf5
# Epoch 24/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6171 - accuracy: 0.6735 - val_loss: 0.6579 - val_accuracy: 0.7021
#
# Epoch 00024: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.24-0.66.hdf5
# Epoch 25/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6479 - accuracy: 0.6323 - val_loss: 0.5843 - val_accuracy: 0.7021
#
# Epoch 00025: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.25-0.58.hdf5
# Epoch 26/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6124 - accuracy: 0.6529 - val_loss: 0.6070 - val_accuracy: 0.7872
#
# Epoch 00026: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.26-0.61.hdf5
# Epoch 27/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6090 - accuracy: 0.6632 - val_loss: 0.4469 - val_accuracy: 0.7447
#
# Epoch 00027: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.27-0.45.hdf5
# Epoch 28/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5598 - accuracy: 0.7148 - val_loss: 0.4936 - val_accuracy: 0.7447
#
# Epoch 00028: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.28-0.49.hdf5
# Epoch 29/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6274 - accuracy: 0.6392 - val_loss: 0.6805 - val_accuracy: 0.7447
#
# Epoch 00029: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.29-0.68.hdf5
# Epoch 30/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6300 - accuracy: 0.6392 - val_loss: 0.5977 - val_accuracy: 0.7872
#
# Epoch 00030: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.30-0.60.hdf5
# Epoch 31/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5669 - accuracy: 0.7285 - val_loss: 0.4462 - val_accuracy: 0.7021
#
# Epoch 00031: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.31-0.45.hdf5
# Epoch 32/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5849 - accuracy: 0.6907 - val_loss: 0.6687 - val_accuracy: 0.7021
#
# Epoch 00032: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.32-0.67.hdf5
# Epoch 33/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6055 - accuracy: 0.6632 - val_loss: 0.4094 - val_accuracy: 0.7660
#
# Epoch 00033: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.33-0.41.hdf5
# Epoch 34/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.6026 - accuracy: 0.6632 - val_loss: 0.5122 - val_accuracy: 0.6800
#
# Epoch 00034: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.34-0.51.hdf5
# Epoch 35/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5862 - accuracy: 0.6735 - val_loss: 0.7710 - val_accuracy: 0.6809
#
# Epoch 00035: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.35-0.77.hdf5
# Epoch 36/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5828 - accuracy: 0.6804 - val_loss: 0.4860 - val_accuracy: 0.8085
#
# Epoch 00036: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.36-0.49.hdf5
# Epoch 37/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.6193 - accuracy: 0.6495 - val_loss: 0.5219 - val_accuracy: 0.6383
#
# Epoch 00037: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.37-0.52.hdf5
# Epoch 38/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5390 - accuracy: 0.7285 - val_loss: 0.7064 - val_accuracy: 0.7660
#
# Epoch 00038: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.38-0.71.hdf5
# Epoch 39/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5831 - accuracy: 0.6735 - val_loss: 0.6205 - val_accuracy: 0.7021
#
# Epoch 00039: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.39-0.62.hdf5
# Epoch 40/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5676 - accuracy: 0.7388 - val_loss: 0.6131 - val_accuracy: 0.7234
#
# Epoch 00040: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.40-0.61.hdf5
# Epoch 41/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5707 - accuracy: 0.7010 - val_loss: 0.3558 - val_accuracy: 0.8511
#
# Epoch 00041: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.41-0.36.hdf5
# Epoch 42/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5748 - accuracy: 0.7079 - val_loss: 0.8169 - val_accuracy: 0.6809
#
# Epoch 00042: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.42-0.82.hdf5
# Epoch 43/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5913 - accuracy: 0.7285 - val_loss: 0.5770 - val_accuracy: 0.7872
#
# Epoch 00043: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.43-0.58.hdf5
# Epoch 44/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5871 - accuracy: 0.6804 - val_loss: 0.4815 - val_accuracy: 0.7660
#
# Epoch 00044: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.44-0.48.hdf5
# Epoch 45/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5742 - accuracy: 0.7216 - val_loss: 0.3486 - val_accuracy: 0.6800
#
# Epoch 00045: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.45-0.35.hdf5
# Epoch 46/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5509 - accuracy: 0.7182 - val_loss: 0.7027 - val_accuracy: 0.7447
#
# Epoch 00046: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.46-0.70.hdf5
# Epoch 47/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5324 - accuracy: 0.7595 - val_loss: 0.3628 - val_accuracy: 0.7234
#
# Epoch 00047: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.47-0.36.hdf5
# Epoch 48/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5254 - accuracy: 0.7251 - val_loss: 0.2148 - val_accuracy: 0.8085
#
# Epoch 00048: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.48-0.21.hdf5
# Epoch 49/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5901 - accuracy: 0.7079 - val_loss: 0.8626 - val_accuracy: 0.7021
#
# Epoch 00049: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.49-0.86.hdf5
# Epoch 50/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5453 - accuracy: 0.7457 - val_loss: 0.6488 - val_accuracy: 0.8085
#
# Epoch 00050: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.50-0.65.hdf5
# Epoch 51/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5236 - accuracy: 0.7285 - val_loss: 0.6182 - val_accuracy: 0.7660
#
# Epoch 00051: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.51-0.62.hdf5
# Epoch 52/150
# 59/59 [==============================] - 65s 1s/step - loss: 0.5199 - accuracy: 0.7766 - val_loss: 0.3818 - val_accuracy: 0.7234
#
# Epoch 00052: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.52-0.38.hdf5
# Epoch 53/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5597 - accuracy: 0.7113 - val_loss: 0.4452 - val_accuracy: 0.7872
#
# Epoch 00053: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.53-0.45.hdf5
# Epoch 54/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5291 - accuracy: 0.7079 - val_loss: 0.4123 - val_accuracy: 0.7447
#
# Epoch 00054: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.54-0.41.hdf5
# Epoch 55/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5570 - accuracy: 0.7388 - val_loss: 0.3280 - val_accuracy: 0.7660
#
# Epoch 00055: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.55-0.33.hdf5
# Epoch 56/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4997 - accuracy: 0.7698 - val_loss: 0.3361 - val_accuracy: 0.7800
#
# Epoch 00056: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.56-0.34.hdf5
# Epoch 57/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5003 - accuracy: 0.7320 - val_loss: 0.2484 - val_accuracy: 0.7872
#
# Epoch 00057: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.57-0.25.hdf5
# Epoch 58/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5151 - accuracy: 0.7663 - val_loss: 0.9067 - val_accuracy: 0.7021
#
# Epoch 00058: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.58-0.91.hdf5
# Epoch 59/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5393 - accuracy: 0.7457 - val_loss: 0.9634 - val_accuracy: 0.7447
#
# Epoch 00059: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.59-0.96.hdf5
# Epoch 60/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5116 - accuracy: 0.7595 - val_loss: 0.7880 - val_accuracy: 0.7447
#
# Epoch 00060: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.60-0.79.hdf5
# Epoch 61/150
# 59/59 [==============================] - 65s 1s/step - loss: 0.4727 - accuracy: 0.7831 - val_loss: 0.6164 - val_accuracy: 0.7234
#
# Epoch 00061: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.61-0.62.hdf5
# Epoch 62/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5203 - accuracy: 0.7491 - val_loss: 0.3090 - val_accuracy: 0.8085
#
# Epoch 00062: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.62-0.31.hdf5
# Epoch 63/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5175 - accuracy: 0.7388 - val_loss: 0.6946 - val_accuracy: 0.7234
#
# Epoch 00063: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.63-0.69.hdf5
# Epoch 64/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4969 - accuracy: 0.7835 - val_loss: 0.7476 - val_accuracy: 0.7234
#
# Epoch 00064: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.64-0.75.hdf5
# Epoch 65/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5212 - accuracy: 0.7388 - val_loss: 0.2696 - val_accuracy: 0.7447
#
# Epoch 00065: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.65-0.27.hdf5
# Epoch 66/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4328 - accuracy: 0.7869 - val_loss: 0.1633 - val_accuracy: 0.7447
#
# Epoch 00066: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.66-0.16.hdf5
# Epoch 67/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.5358 - accuracy: 0.7388 - val_loss: 0.6325 - val_accuracy: 0.7800
#
# Epoch 00067: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.67-0.63.hdf5
# Epoch 68/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4727 - accuracy: 0.7698 - val_loss: 0.3782 - val_accuracy: 0.7872
#
# Epoch 00068: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.68-0.38.hdf5
# Epoch 69/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4669 - accuracy: 0.7663 - val_loss: 0.6328 - val_accuracy: 0.7447
#
# Epoch 00069: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.69-0.63.hdf5
# Epoch 70/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4814 - accuracy: 0.7595 - val_loss: 0.3758 - val_accuracy: 0.7447
#
# Epoch 00070: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.70-0.38.hdf5
# Epoch 71/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4739 - accuracy: 0.7698 - val_loss: 0.5253 - val_accuracy: 0.8085
#
# Epoch 00071: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.71-0.53.hdf5
# Epoch 72/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4832 - accuracy: 0.7663 - val_loss: 0.4425 - val_accuracy: 0.8298
#
# Epoch 00072: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.72-0.44.hdf5
# Epoch 73/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5307 - accuracy: 0.7560 - val_loss: 0.1920 - val_accuracy: 0.7447
#
# Epoch 00073: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.73-0.19.hdf5
# Epoch 74/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5026 - accuracy: 0.7869 - val_loss: 0.5794 - val_accuracy: 0.7660
#
# Epoch 00074: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.74-0.58.hdf5
# Epoch 75/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4676 - accuracy: 0.7526 - val_loss: 0.2414 - val_accuracy: 0.7660
#
# Epoch 00075: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.75-0.24.hdf5
# Epoch 76/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4196 - accuracy: 0.8076 - val_loss: 0.5601 - val_accuracy: 0.8085
#
# Epoch 00076: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.76-0.56.hdf5
# Epoch 77/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4636 - accuracy: 0.7869 - val_loss: 0.1200 - val_accuracy: 0.7660
#
# Epoch 00077: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.77-0.12.hdf5
# Epoch 78/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4398 - accuracy: 0.7869 - val_loss: 0.6624 - val_accuracy: 0.7800
#
# Epoch 00078: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.78-0.66.hdf5
# Epoch 79/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4993 - accuracy: 0.7663 - val_loss: 0.5100 - val_accuracy: 0.7021
#
# Epoch 00079: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.79-0.51.hdf5
# Epoch 80/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5003 - accuracy: 0.7766 - val_loss: 0.1838 - val_accuracy: 0.8723
#
# Epoch 00080: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.80-0.18.hdf5
# Epoch 81/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5099 - accuracy: 0.7560 - val_loss: 0.5597 - val_accuracy: 0.7234
#
# Epoch 00081: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.81-0.56.hdf5
# Epoch 82/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5168 - accuracy: 0.7698 - val_loss: 0.9794 - val_accuracy: 0.7021
#
# Epoch 00082: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.82-0.98.hdf5
# Epoch 83/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4941 - accuracy: 0.7457 - val_loss: 0.4226 - val_accuracy: 0.7872
#
# Epoch 00083: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.83-0.42.hdf5
# Epoch 84/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4731 - accuracy: 0.7698 - val_loss: 0.3008 - val_accuracy: 0.7660
#
# Epoch 00084: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.84-0.30.hdf5
# Epoch 85/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5572 - accuracy: 0.7354 - val_loss: 0.6067 - val_accuracy: 0.7660
#
# Epoch 00085: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.85-0.61.hdf5
# Epoch 86/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4563 - accuracy: 0.7973 - val_loss: 0.7165 - val_accuracy: 0.7660
#
# Epoch 00086: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.86-0.72.hdf5
# Epoch 87/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4380 - accuracy: 0.7869 - val_loss: 0.8866 - val_accuracy: 0.8085
#
# Epoch 00087: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.87-0.89.hdf5
# Epoch 88/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4565 - accuracy: 0.8110 - val_loss: 0.2239 - val_accuracy: 0.7447
#
# Epoch 00088: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.88-0.22.hdf5
# Epoch 89/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4142 - accuracy: 0.8110 - val_loss: 0.4903 - val_accuracy: 0.7200
#
# Epoch 00089: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.89-0.49.hdf5
# Epoch 90/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4677 - accuracy: 0.7801 - val_loss: 0.4495 - val_accuracy: 0.8298
#
# Epoch 00090: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.90-0.45.hdf5
# Epoch 91/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4595 - accuracy: 0.7938 - val_loss: 0.7073 - val_accuracy: 0.6809
#
# Epoch 00091: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.91-0.71.hdf5
# Epoch 92/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5446 - accuracy: 0.7216 - val_loss: 0.2552 - val_accuracy: 0.7660
#
# Epoch 00092: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.92-0.26.hdf5
# Epoch 93/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5261 - accuracy: 0.7388 - val_loss: 0.4883 - val_accuracy: 0.7872
#
# Epoch 00093: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.93-0.49.hdf5
# Epoch 94/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4584 - accuracy: 0.7766 - val_loss: 0.2961 - val_accuracy: 0.8085
#
# Epoch 00094: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.94-0.30.hdf5
# Epoch 95/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4967 - accuracy: 0.7491 - val_loss: 0.6118 - val_accuracy: 0.7234
#
# Epoch 00095: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.95-0.61.hdf5
# Epoch 96/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5026 - accuracy: 0.7732 - val_loss: 0.9547 - val_accuracy: 0.7660
#
# Epoch 00096: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.96-0.95.hdf5
# Epoch 97/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4767 - accuracy: 0.7526 - val_loss: 0.4304 - val_accuracy: 0.7660
#
# Epoch 00097: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.97-0.43.hdf5
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 98/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.5182 - accuracy: 0.7423 - val_loss: 0.3494 - val_accuracy: 0.8085
#
# Epoch 00098: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.98-0.35.hdf5
# Epoch 99/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4338 - accuracy: 0.7938 - val_loss: 0.2650 - val_accuracy: 0.8085
#
# Epoch 00099: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.99-0.26.hdf5
# Epoch 100/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4224 - accuracy: 0.8041 - val_loss: 0.3392 - val_accuracy: 0.8000
#
# Epoch 00100: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.100-0.34.hdf5
# Epoch 101/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4542 - accuracy: 0.7869 - val_loss: 0.2952 - val_accuracy: 0.8298
#
# Epoch 00101: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.101-0.30.hdf5
# Epoch 102/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4359 - accuracy: 0.8041 - val_loss: 0.2150 - val_accuracy: 0.7447
#
# Epoch 00102: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.102-0.21.hdf5
# Epoch 103/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4363 - accuracy: 0.7869 - val_loss: 0.8673 - val_accuracy: 0.8085
#
# Epoch 00103: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.103-0.87.hdf5
# Epoch 104/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4305 - accuracy: 0.8007 - val_loss: 0.1978 - val_accuracy: 0.7872
#
# Epoch 00104: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.104-0.20.hdf5
# Epoch 105/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4273 - accuracy: 0.8041 - val_loss: 0.5495 - val_accuracy: 0.7872
#
# Epoch 00105: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.105-0.55.hdf5
# Epoch 106/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4347 - accuracy: 0.8007 - val_loss: 0.2887 - val_accuracy: 0.7660
#
# Epoch 00106: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.106-0.29.hdf5
# Epoch 107/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4627 - accuracy: 0.7869 - val_loss: 0.5986 - val_accuracy: 0.7660
#
# Epoch 00107: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.107-0.60.hdf5
# Epoch 108/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4147 - accuracy: 0.8316 - val_loss: 0.8887 - val_accuracy: 0.8511
#
# Epoch 00108: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.108-0.89.hdf5
# Epoch 109/150
# 59/59 [==============================] - 62s 1s/step - loss: 0.4319 - accuracy: 0.8247 - val_loss: 0.1063 - val_accuracy: 0.8511
#
# Epoch 00109: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.109-0.11.hdf5
# Epoch 110/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4305 - accuracy: 0.7801 - val_loss: 0.1852 - val_accuracy: 0.7447
#
# Epoch 00110: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.110-0.19.hdf5
# Epoch 111/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.3969 - accuracy: 0.8351 - val_loss: 0.2859 - val_accuracy: 0.8400
#
# Epoch 00111: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.111-0.29.hdf5
# Epoch 112/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4183 - accuracy: 0.8144 - val_loss: 0.4147 - val_accuracy: 0.8511
#
# Epoch 00112: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.112-0.41.hdf5
# Epoch 113/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4169 - accuracy: 0.8213 - val_loss: 1.1572 - val_accuracy: 0.7447
#
# Epoch 00113: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.113-1.16.hdf5
# Epoch 114/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3811 - accuracy: 0.8419 - val_loss: 0.5313 - val_accuracy: 0.7447
#
# Epoch 00114: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.114-0.53.hdf5
# Epoch 115/150
# 59/59 [==============================] - 62s 1s/step - loss: 0.4773 - accuracy: 0.7904 - val_loss: 0.5584 - val_accuracy: 0.8298
#
# Epoch 00115: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.115-0.56.hdf5
# Epoch 116/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3918 - accuracy: 0.8488 - val_loss: 0.4111 - val_accuracy: 0.7447
#
# Epoch 00116: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.116-0.41.hdf5
# Epoch 117/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4093 - accuracy: 0.8213 - val_loss: 0.4776 - val_accuracy: 0.7660
#
# Epoch 00117: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.117-0.48.hdf5
# Epoch 118/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4625 - accuracy: 0.7973 - val_loss: 0.3231 - val_accuracy: 0.8723
#
# Epoch 00118: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.118-0.32.hdf5
# Epoch 119/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4269 - accuracy: 0.8179 - val_loss: 0.5657 - val_accuracy: 0.7872
#
# Epoch 00119: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.119-0.57.hdf5
# Epoch 120/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3897 - accuracy: 0.8179 - val_loss: 0.4108 - val_accuracy: 0.7447
#
# Epoch 00120: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.120-0.41.hdf5
# Epoch 121/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.4170 - accuracy: 0.7932 - val_loss: 0.3370 - val_accuracy: 0.8298
#
# Epoch 00121: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.121-0.34.hdf5
# Epoch 122/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3681 - accuracy: 0.8282 - val_loss: 0.1901 - val_accuracy: 0.8200
#
# Epoch 00122: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.122-0.19.hdf5
# Epoch 123/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4165 - accuracy: 0.8247 - val_loss: 0.3107 - val_accuracy: 0.8511
#
# Epoch 00123: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.123-0.31.hdf5
# Epoch 124/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.3589 - accuracy: 0.8316 - val_loss: 0.1915 - val_accuracy: 0.8511
#
# Epoch 00124: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.124-0.19.hdf5
# Epoch 125/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4089 - accuracy: 0.8213 - val_loss: 0.1736 - val_accuracy: 0.7234
#
# Epoch 00125: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.125-0.17.hdf5
# Epoch 126/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.3552 - accuracy: 0.8522 - val_loss: 0.3133 - val_accuracy: 0.8298
#
# Epoch 00126: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.126-0.31.hdf5
# Epoch 127/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3995 - accuracy: 0.8316 - val_loss: 0.1686 - val_accuracy: 0.8511
#
# Epoch 00127: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.127-0.17.hdf5
# Epoch 128/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4450 - accuracy: 0.8007 - val_loss: 0.7264 - val_accuracy: 0.7660
#
# Epoch 00128: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.128-0.73.hdf5
# Epoch 129/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3799 - accuracy: 0.8557 - val_loss: 0.4337 - val_accuracy: 0.8298
#
# Epoch 00129: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.129-0.43.hdf5
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 130/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4498 - accuracy: 0.8076 - val_loss: 0.8241 - val_accuracy: 0.8723
#
# Epoch 00130: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.130-0.82.hdf5
# Epoch 131/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3914 - accuracy: 0.8282 - val_loss: 0.3663 - val_accuracy: 0.8511
#
# Epoch 00131: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.131-0.37.hdf5
# Epoch 132/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4004 - accuracy: 0.8385 - val_loss: 0.2200 - val_accuracy: 0.8511
#
# Epoch 00132: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.132-0.22.hdf5
# Epoch 133/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3361 - accuracy: 0.8694 - val_loss: 0.5743 - val_accuracy: 0.7200
#
# Epoch 00133: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.133-0.57.hdf5
# Epoch 134/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3916 - accuracy: 0.8213 - val_loss: 0.6507 - val_accuracy: 0.7447
#
# Epoch 00134: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.134-0.65.hdf5
# Epoch 135/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4312 - accuracy: 0.8041 - val_loss: 0.1646 - val_accuracy: 0.8723
#
# Epoch 00135: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.135-0.16.hdf5
# Epoch 136/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4290 - accuracy: 0.8110 - val_loss: 0.6670 - val_accuracy: 0.7660
#
# Epoch 00136: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.136-0.67.hdf5
# Epoch 137/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3657 - accuracy: 0.8351 - val_loss: 0.1923 - val_accuracy: 0.8298
#
# Epoch 00137: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.137-0.19.hdf5
# Epoch 138/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4316 - accuracy: 0.8282 - val_loss: 0.1609 - val_accuracy: 0.8298
#
# Epoch 00138: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.138-0.16.hdf5
# Epoch 139/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3632 - accuracy: 0.8454 - val_loss: 0.6954 - val_accuracy: 0.7021
#
# Epoch 00139: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.139-0.70.hdf5
# Epoch 140/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3848 - accuracy: 0.8385 - val_loss: 0.7170 - val_accuracy: 0.7872
#
# Epoch 00140: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.140-0.72.hdf5
# Epoch 141/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3779 - accuracy: 0.8419 - val_loss: 0.3755 - val_accuracy: 0.9149
#
# Epoch 00141: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.141-0.38.hdf5
# Epoch 142/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3741 - accuracy: 0.8076 - val_loss: 0.9998 - val_accuracy: 0.8085
#
# Epoch 00142: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.142-1.00.hdf5
# Epoch 143/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3628 - accuracy: 0.8179 - val_loss: 0.0213 - val_accuracy: 0.8936
#
# Epoch 00143: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.143-0.02.hdf5
# Epoch 144/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3942 - accuracy: 0.8316 - val_loss: 0.5547 - val_accuracy: 0.8000
#
# Epoch 00144: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.144-0.55.hdf5
# Epoch 145/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3236 - accuracy: 0.8385 - val_loss: 0.3807 - val_accuracy: 0.8511
#
# Epoch 00145: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.145-0.38.hdf5
# Epoch 146/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.3700 - accuracy: 0.8419 - val_loss: 0.3074 - val_accuracy: 0.7660
#
# Epoch 00146: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.146-0.31.hdf5
# Epoch 147/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4108 - accuracy: 0.8213 - val_loss: 0.2488 - val_accuracy: 0.8085
#
# Epoch 00147: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.147-0.25.hdf5
# Epoch 148/150
# 59/59 [==============================] - 64s 1s/step - loss: 0.3581 - accuracy: 0.8351 - val_loss: 0.3596 - val_accuracy: 0.8723
#
# Epoch 00148: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.148-0.36.hdf5
# Epoch 149/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.4347 - accuracy: 0.8110 - val_loss: 0.1375 - val_accuracy: 0.7660
#
# Epoch 00149: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.149-0.14.hdf5
# Epoch 150/150
# 59/59 [==============================] - 63s 1s/step - loss: 0.2851 - accuracy: 0.9003 - val_loss: 0.3775 - val_accuracy: 0.8298
#
# Epoch 00150: saving model to /content/drive/My Drive/Deep Learning/Sub_32/Models/T3D_saved_model_weights.150-0.38.hdf5

# %%
import matplotlib.pyplot as plt
train_loss=history.history['loss']
val_loss=history.history['val_loss']
train_acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
xc=range(150)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss, 'b', color='red')
plt.plot(xc,val_loss,'--', color = 'blue' )
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.ylim(0, 1.8)
plt.title('Training Loss vs Validation Loss')
plt.grid(True)
plt.legend(['Training Loss','Validation Loss'])
#print (plt.style.available) # use bmh, classic,ggplot for big pictures
plt.style.use(['seaborn'])

plt.figure(2,figsize=(7,5))
plt.plot(xc,train_acc, 'b', color = 'red')
plt.plot(xc,val_acc, '--', color = 'blue')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylim(0, 1)

plt.grid(True)
plt.legend(['Training Accuracy','Validation Accuracy'],loc=4)
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['seaborn'])
